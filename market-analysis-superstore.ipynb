# %% [markdown]
# <a href="https://www.kaggle.com/code/zaimasyarifaasshafa/market-analysis-superstore?scriptVersionId=254810112" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ![SUPERSTORE.png](attachment:54602afa-312f-4fbe-b665-590aab95fcc6.png)

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; max-width: 850px; margin: auto;">
#
# <h1 style="text-align: center; color: #322083; background-color: #e8e3ff; padding: 10px; border-radius: 8px;">
#   📘 Business Understanding
# </h1>
#
# <hr style="border: 1px solid #ccc; margin: 25px 0;">
#
# <h2 style="color: #7475c5;">🏢 1.1 About Company: Superstore</h2>
# <p style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   Superstore is a mid-to-large scale retail company that sells a wide range of consumer and business products, including furniture, office supplies, and technology.
#   The product catalog spans various sub-categories such as Chairs, Tables, Binders, Phones, and Machines.
# </p>
# <p style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   Sales are conducted through multiple channels, reaching both local and international customers, supported by various shipping methods. As a data-rich company that relies heavily on sales volume, Superstore recognizes the importance of using data analytics to better understand customer behavior, product performance, and market dynamics to drive smarter business decisions.
# </p>
#
# <h2 style="color: #7475c5;">⚠️ 1.2 Problem Background</h2>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7; background-color: #f5f5ff; padding: 10px 20px; border-left: 4px solid #749def; border-radius: 6px;">
#   <li>Lack of visibility into the performance of individual products.</li>
#   <li>Uncertainty around which products or categories are the most profitable.</li>
#   <li>Customer segmentation and shipping preferences have not been analyzed comprehensively.</li>
#   <li>A need for deeper understanding of market dynamics and sales trends based on time and location.</li>
# </ul>
#
# <h2 style="color: #7475c5;">🎯 1.3 Goals</h2>
# <p style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   To improve the effectiveness of business strategy through data-driven insights by:
# </p>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   <li>✅ Identifying the top-selling and most profitable products, categories, and subcategories.</li>
#   <li>👥 Understanding the contribution of each customer segment to overall profitability.</li>
#   <li>🌍 Analyzing market performance across regions and countries.</li>
#   <li>🚚 Evaluating purchasing patterns based on shipping modes, time (year/month), and location.</li>
#   <li>📊 Delivering insightful visualizations to support managerial decision-making.</li>
# </ul>
#
# <h2 style="color: #7475c5;">🛠️ 1.4 Objective</h2>
# <p style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   To address key business questions, the analysis will focus on the following structured objectives:
# </p>
#
# <h3 style="color: #322083;">📦 Product Performance Analysis</h3>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   <li>🔥 Identify the most selling products.</li>
#   <li>💰 Determine the top 10 products by total sales value.</li>
#   <li>📈 Identify the most profitable products.</li>
# </ul>
#
# <h3 style="color: #322083;">🗂️ Category Analysis</h3>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   <li>🏆 Identify categories with the highest sales and profits.</li>
#   <li>🧾 Calculate total sales values by category and subcategory.</li>
#   <li>🔍 Identify best-selling products within each subcategory.</li>
# </ul>
#
# <h3 style="color: #322083;">👥 Customer Analysis</h3>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   <li>💎 Analyze the most profitable customer segments.</li>
#   <li>🥇 Identify the top 10 most profitable customers.</li>
# </ul>
#
# <h3 style="color: #322083;">🚚 Shipping & Logistics</h3>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   <li>🚛 Identify the shipping modes with the highest product volumes.</li>
#   <li>📦 Visualize product category performance by shipping mode.</li>
# </ul>
#
# <h3 style="color: #322083;">🌍 Market & Geography Insights</h3>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   <li>🌎 Determine which markets or regions generate the highest sales.</li>
#   <li>🏅 Identify the top 10 countries by total sales.</li>
#   <li>💸 Calculate the average shipping cost for the top 10 countries.</li>
# </ul>
#
# <h3 style="color: #322083;">📅 Time-Based Analysis</h3>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   <li>📆 Calculate and visualize total sales values by year and month to understand seasonal trends.</li>
# </ul>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; max-width: 850px; margin: auto;">
#
# <h1 style="text-align: center; color: #322083; background-color: #e8e3ff; padding: 10px; border-radius: 8px">
#   📘 Data Understanding
# </h1>
#
# <hr style="border: 1px solid #ccc; margin: 25px 0;">

# %% [markdown]
# <h2 style="color: #7475c5;">2.1 Import Library & Read Data</h2>

# %%
# Import necesary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

from datetime import datetime
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# setting display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Read dataset
sales = pd.read_excel('/kaggle/input/superstore-sales/superstore_sales.xlsx')

# %% [markdown]
# <h2 style="color: #7475c5;">2.2 Data Exploration</h2>

# %% [markdown]
# | Feature           | Description                                                                 |
# |-------------------|-----------------------------------------------------------------------------|
# | `order_id`        | Unique identifier for each order.                                           |
# | `order_date`      | The date when the order was placed.                                         |
# | `ship_date`       | The date when the order was shipped.                                        |
# | `ship_mode`       | The shipping method used for delivery (e.g., Standard Class, First Class).  |
# | `customer_name`   | Name of the customer who placed the order.                                  |
# | `segment`         | Customer segment (e.g., Consumer, Corporate, Home Office).                  |
# | `state`           | The state/province where the customer is located.                           |
# | `country`         | The country where the customer is located.                                  |
# | `market`          | Market region classification (e.g., APAC, EMEA, US).                        |
# | `region`          | Geographical region (e.g., West, East, Central, South).                     |
# | `product_id`      | Unique identifier for each product.                                         |
# | `category`        | Product's main category (e.g., Furniture, Office Supplies, Technology).     |
# | `sub_category`    | Product's sub-category (e.g., Chairs, Binders, Phones).                     |
# | `product_name`    | The name of the product.                                                    |
# | `sales`           | The total sales amount for the order line.                                 |
# | `quantity`        | The number of units sold.                                                  |
# | `discount`        | Discount applied to the order line (as a proportion, e.g., 0.2 for 20%).    |
# | `profit`          | Profit earned from the sale.                                               |
# | `shipping_cost`   | The cost of shipping for the order line.                                    |
# | `order_priority`  | Priority level of the order (e.g., High, Medium, Low, Critical).            |
# | `year`            | The year in which the order was placed.                                     |

# %%
sales.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region        product_id  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  OFF-TEN-10000025
# 1     Consumer  New South Wales  Australia    APAC  Oceania   OFF-SU-10000618
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  OFF-TEN-10001585
# 3  Home Office        Stockholm     Sweden      EU    North   OFF-PA-10001492
# 4     Consumer  New South Wales  Australia    APAC  Oceania   FUR-FU-10003447
#
#           category sub_category                 product_name    sales  \
# 0  Office Supplies      Storage          Tenex Lockers, Blue  408.300
# 1  Office Supplies     Supplies     Acme Trimmer, High Speed  120.366
# 2  Office Supplies      Storage      Tenex Box, Single Width   66.120
# 3  Office Supplies        Paper  Enermax Note Cards, Premium   44.865
# 4        Furniture  Furnishings   Eldon Light Bulb, Duo Pack  113.670
#
#    quantity  discount   profit  shipping_cost order_priority  year
# 0         2       0.0  106.140          35.46         Medium  2011
# 1         3       0.1   36.036           9.72         Medium  2011
# 2         4       0.0   29.640           8.17           High  2011
# 3         3       0.5  -26.055           4.82           High  2011
# 4         5       0.1   37.770           4.70         Medium  2011

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  datetime64[ns]
#  2   ship_date       51290 non-null  datetime64[ns]
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  float64
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
#  18  shipping_cost   51290 non-null  float64
#  19  order_priority  51290 non-null  object
#  20  year            51290 non-null  int64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(13)
# memory usage: 8.2+ MB

# %%
# Check Missing values
sales.isnull().sum().any()
# Out:
# False

# %%
# Num uniq values of Order ID
sales['order_id'].nunique()
# Out:
# 25035

# %%
#  Check Duplicated Data
sales.duplicated().sum()
# Out:
# 0

# %%
sales['order_id'].duplicated().sum()
# Out:
# 26255

# %%
# Count the number of item rows for each Order ID
sales['order_id'].value_counts().sort_values(ascending=False).head(10)
# Out:
# order_id
# CA-2014-100111     14
# TO-2014-9950       13
# NI-2014-8880       13
# IN-2013-42311      13
# IN-2012-41261      13
# MX-2014-166541     13
# IN-2011-76625      12
# ES-2012-5776825    12
# IN-2014-15263      12
# MX-2013-142678     12
# Name: count, dtype: int64

# %%
# Order IDs that have multiple item rows within a single orde
sales[sales['order_id']=="CA-2014-100111"]
# Out:
#              order_id order_date  ship_date       ship_mode customer_name  \
# 44726  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44727  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44728  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44730  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44731  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44732  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44733  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44735  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44736  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44738  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44739  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44740  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44741  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
# 44742  CA-2014-100111 2014-09-21 2014-09-27  Standard Class   Seth Vernon
#
#         segment     state        country market region       product_id  \
# 44726  Consumer  New York  United States     US   East  FUR-CH-10004086
# 44727  Consumer  New York  United States     US   East  FUR-CH-10001215
# 44728  Consumer  New York  United States     US   East  TEC-PH-10002885
# 44730  Consumer  New York  United States     US   East  FUR-CH-10003846
# 44731  Consumer  New York  United States     US   East  TEC-AC-10002647
# 44732  Consumer  New York  United States     US   East  TEC-PH-10000215
# 44733  Consumer  New York  United States     US   East  FUR-CH-10003061
# 44735  Consumer  New York  United States     US   East  TEC-AC-10001998
# 44736  Consumer  New York  United States     US   East  TEC-AC-10001465
# 44738  Consumer  New York  United States     US   East  OFF-ST-10000615
# 44739  Consumer  New York  United States     US   East  OFF-PA-10000807
# 44740  Consumer  New York  United States     US   East  OFF-PA-10002713
# 44741  Consumer  New York  United States     US   East  OFF-BI-10000343
# 44742  Consumer  New York  United States     US   East  OFF-FA-10000304
#
#               category sub_category  \
# 44726        Furniture       Chairs
# 44727        Furniture       Chairs
# 44728       Technology       Phones
# 44730        Furniture       Chairs
# 44731       Technology  Accessories
# 44732       Technology       Phones
# 44733        Furniture       Chairs
# 44735       Technology  Accessories
# 44736       Technology  Accessories
# 44738  Office Supplies      Storage
# 44739  Office Supplies        Paper
# 44740  Office Supplies        Paper
# 44741  Office Supplies      Binders
# 44742  Office Supplies    Fasteners
#
#                                             product_name     sales  quantity  \
# 44726  Hon 4070 Series Pagoda Armless Upholstered Sta...  2888.127        11
# 44727      Global Troy Executive Leather Low-Back Tilter  2254.410         5
# 44728                                     Apple iPhone 5  1299.660         2
# 44730                         Hon Valutask Swivel Chairs   272.646         3
# 44731  Logitech Wireless Boombox Speaker - portable -...   212.800         2
# 44732  Plantronics Cordless Phone Headset with In-lin...   104.850         3
# 44733                   Global Leather Task Chair, Black    80.991         1
# 44735  Logitech LS21 Speaker System - PC Multimedia -...    59.970         3
# 44736               SanDisk Cruzer 64 GB USB Flash Drive    72.640         2
# 44738  SimpliFile Personal File, Black Granite, 15w x...    45.400         4
# 44739  TOPS "Important Message" Pads, Canary, 4-1/4 x...    38.520         9
# 44740  Adams Phone Message Book, 200 Message Capacity...    13.760         2
# 44741  Pressboard Covers with Storage Hooks, 9 1/2" x...    11.784         3
# 44742                                 Advantus Push Pins     4.360         2
#
#        discount    profit  shipping_cost order_priority  year
# 44726       0.1  609.7157         177.06         Medium  2014
# 44727       0.1  375.7350         175.20         Medium  2014
# 44728       0.0  350.9082          53.23         Medium  2014
# 44730       0.1   18.1764          29.25         Medium  2014
# 44731       0.0   95.7600          15.57         Medium  2014
# 44732       0.0   28.3095           8.25         Medium  2014
# 44733       0.1    8.0991           7.78         Medium  2014
# 44735       0.0   20.3898           3.42         Medium  2014
# 44736       0.0   21.7920           2.48         Medium  2014
# 44738       0.0   12.7120           1.91         Medium  2014
# 44739       0.0   18.1044           1.88         Medium  2014
# 44740       0.0    6.3296           1.35         Medium  2014
# 44741       0.2    3.9771           1.28         Medium  2014
# 44742       0.0    1.7876           0.26         Medium  2014

# %%
# Num of unique value
for col in sales.columns:
    print(f"{col}: {sales[col].nunique()}")
# Out:
# order_id: 25035
# order_date: 1430
# ship_date: 1464
# ship_mode: 4
# customer_name: 795
# segment: 3
# state: 1094
# country: 147
# market: 7
# region: 13
# product_id: 10292
# category: 3
# sub_category: 17
# product_name: 3788
# sales: 27200
# quantity: 14
# discount: 29
# profit: 28234
# shipping_cost: 17095
# order_priority: 4
# year: 4

# %%
col_cat = sales[['ship_mode', 'segment', 'market', 'region', 'category', 'sub_category', 'order_priority', 'year']]

# %%
# Value count for categorical cols
for col in col_cat:
    print(sales[col].value_counts())
    print("-"*50)
# Out:
# ship_mode
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: count, dtype: int64
# --------------------------------------------------
# segment
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: count, dtype: int64
# --------------------------------------------------
# market
# APAC      11002
# LATAM     10294
# EU        10000
# US         9994
# EMEA       5029
# Africa     4587
# Canada      384
# Name: count, dtype: int64
# --------------------------------------------------
# region
# Central           11117
# South              6645
# EMEA               5029
# North              4785
# Africa             4587
# Oceania            3487
# West               3203
# Southeast Asia     3129
# East               2848
# North Asia         2338
# Central Asia       2048
# Caribbean          1690
# Canada              384
# Name: count, dtype: int64
# --------------------------------------------------
# category
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: count, dtype: int64
# --------------------------------------------------
# sub_category
# Binders        6152
# Storage        5059
# Art            4883
# Paper          3538
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Labels         2606
# Envelopes      2435
# Supplies       2425
# Fasteners      2420
# Bookcases      2411
# Copiers        2223
# Appliances     1755
# Machines       1486
# Tables          861
# Name: count, dtype: int64
# --------------------------------------------------
# order_priority
# Medium      29433
# High        15501
# Critical     3932
# Low          2424
# Name: count, dtype: int64
# --------------------------------------------------
# year
# 2014    17531
# 2013    13799
# 2012    10962
# 2011     8998
# Name: count, dtype: int64
# --------------------------------------------------

# %% [markdown]
# <h3 style="color: #322083;">⚠️ Product ID Inconsistency</h3>

# %%
# Verify if each Product ID corresponds to one unique product
sales.groupby('product_id')['product_name'].nunique().sort_values(ascending=False).head()
# Out:
# product_id
# OFF-PA-10004673    4
# OFF-SU-10003629    3
# FUR-FU-10004960    3
# TEC-AC-10003063    3
# OFF-BI-10004632    3
# Name: product_name, dtype: int64

# %% [markdown]
# Some product IDs are associated with more than one unique product name.

# %%
# A Product ID with four unique products
sales[sales['product_id'] == 'OFF-PA-10004673']['product_name'].unique()
# Out:
# array(['Enermax Message Books, 8.5 x 11', 'Eaton Note Cards, Multicolor',
#        'Xerox Message Books, Multicolor',
#        'Green Bar Memo Slips, Recycled'], dtype=object)

# %%
sales[sales['product_id'] == 'OFF-PA-10004673']['sub_category'].unique()
# Out:
# array(['Paper'], dtype=object)

# %%
sales[sales['product_id'] == 'OFF-PA-10004673']
# Out:
#             order_id order_date  ship_date       ship_mode      customer_name  \
# 9209   ID-2012-41408 2012-01-12 2012-01-17  Standard Class           Rob Dowd
# 10228  IN-2012-39889 2012-03-14 2012-03-14        Same Day            Jim Epp
# 16066  IN-2012-83170 2012-09-26 2012-09-30    Second Class       Mark Cousins
# 24903  ID-2013-46427 2013-06-20 2013-06-24  Standard Class     Nicole Brennan
# 29447  ID-2013-61946 2013-09-30 2013-10-06  Standard Class     Mike Pelletier
# 31763  ID-2013-80125 2013-11-22 2013-11-27    Second Class       Shaun Chance
# 38252  ID-2014-80657 2014-05-16 2014-05-18    Second Class  Russell D'Ascenzo
# 45651  IN-2014-81546 2014-10-06 2014-10-11  Standard Class  Phillip Flathmann
# 47185  ID-2014-83415 2014-11-04 2014-11-09    Second Class        Daniel Lacy
#
#            segment             state      country market          region  \
# 9209      Consumer  National Capital  Philippines   APAC  Southeast Asia
# 10228    Corporate          Shandong        China   APAC      North Asia
# 16066    Corporate        Wellington  New Zealand   APAC         Oceania
# 24903    Corporate  National Capital  Philippines   APAC  Southeast Asia
# 29447  Home Office             Seoul  South Korea   APAC      North Asia
# 31763    Corporate          Auckland  New Zealand   APAC         Oceania
# 38252     Consumer          Auckland  New Zealand   APAC         Oceania
# 45651     Consumer        Wellington  New Zealand   APAC         Oceania
# 47185     Consumer          Victoria    Australia   APAC         Oceania
#
#             product_id         category sub_category  \
# 9209   OFF-PA-10004673  Office Supplies        Paper
# 10228  OFF-PA-10004673  Office Supplies        Paper
# 16066  OFF-PA-10004673  Office Supplies        Paper
# 24903  OFF-PA-10004673  Office Supplies        Paper
# 29447  OFF-PA-10004673  Office Supplies        Paper
# 31763  OFF-PA-10004673  Office Supplies        Paper
# 38252  OFF-PA-10004673  Office Supplies        Paper
# 45651  OFF-PA-10004673  Office Supplies        Paper
# 47185  OFF-PA-10004673  Office Supplies        Paper
#
#                           product_name   sales  quantity  discount  profit  \
# 9209   Enermax Message Books, 8.5 x 11  43.956         3      0.45 -15.264
# 10228  Enermax Message Books, 8.5 x 11  53.280         2      0.00  13.800
# 16066     Eaton Note Cards, Multicolor  61.440         2      0.00  15.360
# 24903  Enermax Message Books, 8.5 x 11  73.260         5      0.45 -25.440
# 29447  Enermax Message Books, 8.5 x 11  26.640         2      0.50 -12.840
# 31763     Eaton Note Cards, Multicolor  18.432         1      0.40  -4.608
# 38252  Xerox Message Books, Multicolor  26.136         2      0.40 -14.844
# 45651   Green Bar Memo Slips, Recycled  67.440         4      0.00  21.480
# 47185   Green Bar Memo Slips, Recycled  10.116         1      0.40  -1.374
#
#        shipping_cost order_priority  year
# 9209            3.10         Medium  2012
# 10228           4.31           High  2012
# 16066          11.69           High  2012
# 24903           5.35           High  2013
# 29447           1.32         Medium  2013
# 31763           0.96         Medium  2013
# 38252           2.99           High  2014
# 45651           3.58         Medium  2014
# 47185           1.00         Medium  2014

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; max-width: 850px; margin: auto;">
#
# <h1 style="color: #322083; padding: 10px; border-radius: 8px;">
#   💡 Insight
# </h1>
#
# <hr style="border: 1px solid #ccc; margin: 25px 0;">
#
# <h3 style="color: #7475c5;">📊 Data Overview & Quality Insights</h3>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   <li>The dataset consists of <strong>51,290 rows</strong> and <strong>21 columns</strong>, capturing transactional sales data from <strong>2011 to 2014</strong>.</li>
#   <li>✅ <strong>No missing values</strong> in any column, indicating complete and well-recorded data.</li>
#   <li>📌 All columns have appropriate data types: date, numerical, and categorical types — suitable for analysis.</li>
#   <li>🔎 No duplicate records found — each row represents a <strong>unique item-level transaction</strong>.</li>
#   <li>🧾 Each <strong>Order ID</strong> may include <strong>1 to 14 product items</strong>, reflecting bundled purchases.</li>
# </ul>
#
# <h3 style="color: #7475c5;">👥 Customer Segmentation</h3>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   <li>The dataset covers three customer segments:</li>
#   <ul style="list-style-type: circle; padding-left: 25px;">
#     <li><strong>Consumer</strong> 🛍️ — highest number of transactions, mostly individual buyers.</li>
#     <li><strong>Corporate</strong> 🏢 — businesses placing medium-large orders.</li>
#     <li><strong>Home Office</strong> 🧑‍💻 — freelancers or small business operators working from home.</li>
#   </ul>
# </ul>
#
# <h3 style="color: #7475c5;">🚚 Shipping Modes & Order Priorities</h3>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   <li>There are four shipping modes available:</li>
#   <ul style="list-style-type: circle; padding-left: 25px;">
#     <li>📦 <strong>Standard Class</strong> — most frequently used</li>
#     <li>📦 <strong>Second Class</strong></li>
#     <li>📦 <strong>First Class</strong></li>
#     <li>⚡ <strong>Same Day</strong> — fastest shipping option</li>
#   </ul>
#   <li>🧭 The dataset also includes four order priority levels:</li>
#   <ul style="list-style-type: circle; padding-left: 25px;">
#     <li>🔵 Low</li>
#     <li>🟡 Medium</li>
#     <li>🟠 High</li>
#     <li>🔴 Critical</li>
#   </ul>
#   <li>These priorities likely influence shipping speed and urgency of fulfillment.</li>
# </ul>
#
# <h3 style="color: #7475c5;">🛒 Product Information</h3>
# <ul style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   <li>Products are categorized into three main categories:</li>
#   <ul style="list-style-type: circle; padding-left: 25px;">
#     <li>📁 Office Supplies</li>
#     <li>🪑 Furniture</li>
#     <li>💻 Technology</li>
#   </ul>
#   <li>These are further divided into <strong>17 sub-categories</strong>.</li>
#   <li>Total of <strong>3,788 unique products</strong> sold during the period.</li>
# </ul>
#
# <h3 style="color: #7475c5;">⚠️ Product ID Inconsistency</h3>
# <p style="font-size: 16px; color: #2f2f2f; line-height: 1.7; background-color: #fef7f7; padding: 12px 20px; border-left: 4px solid #ff6b6b; border-radius: 6px;">
#   Although the dataset includes a <strong>product_id</strong> column, some IDs (e.g., <code>OFF-PA-10004673</code>) are associated with <strong>multiple product names</strong>, suggesting possible data entry issues or label mismatches.
# </p>
#
# <h3 style="color: #7475c5;">🧭 Assumption Used in the Analysis</h3>
# <p style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   Since there's no available product master reference and <strong>product_name</strong> appears to be more consistent and descriptive, this analysis treats <strong>product_name</strong> as the <em>primary identifier</em> for unique products.
# </p>
# <p style="font-size: 16px; color: #2f2f2f; line-height: 1.7;">
#   All aggregations, groupings, and product-based analysis are based on <strong>product_name</strong> instead of <code>product_id</code>.
# </p>
#
# </div>

# %% [markdown]
# <h3 style="color: #322083; background-color: #e8e3ff; padding: 10px; border-radius: 8px;">⊹ . ݁˖ . ݁📅 Time-Based Overview . ݁₊ ⊹ . ݁</h3>

# %% [markdown]
# <h3 style="color: #322083;">1. 📅Sales Values by Year and Month</h3>

# %%
sales['year'] = sales['order_date'].dt.year
sales['month'] = sales['order_date'].dt.to_period('M').astype(str)

# %%
# Total sales by year
sales_by_year = sales.groupby('year')['sales'].sum().reset_index()

# Visualisasi
fig = px.line(sales_by_year, x='year', y='sales', title='Yearly Sales Over Time')

# Paksa tick sumbu X hanya tahun bulat
fig.update_layout(
    xaxis=dict(
        tickmode='linear',
        dtick=1
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8f783a90-a45a-4aac-b323-5fa541af24dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f783a90-a45a-4aac-b323-5fa541af24dd")) {                    Plotly.newPlot(                        "8f783a90-a45a-4aac-b323-5fa541af24dd",                        [{"hovertemplate":"year=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2011,2012,2013,2014],"xaxis":"x","y":[2259450.89554,2677438.6944,3405746.44938,4299865.87056],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %%
sales_by_month = sales.groupby('month')['sales'].sum().reset_index()

fig = px.line(sales_by_month, x='month', y='sales', title='Monthly Sales Over Time')
fig.update_xaxes(tickangle=45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6e15df3f-90ef-4a3e-b6cf-f94e73a47f1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e15df3f-90ef-4a3e-b6cf-f94e73a47f1f")) {                    Plotly.newPlot(                        "6e15df3f-90ef-4a3e-b6cf-f94e73a47f1f",                        [{"hovertemplate":"month=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2011-01","2011-02","2011-03","2011-04","2011-05","2011-06","2011-07","2011-08","2011-09","2011-10","2011-11","2011-12","2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12"],"xaxis":"x","y":[98898.48886,91152.15698,145729.36736,116915.76418,146747.8361,215207.38022,115510.41912,207581.49122,290214.45534,199071.26404,298496.53752,333925.7346,135780.72024,100510.21698,163076.77116,161052.26952,208364.89124,256175.69842,145236.78512000002,303142.94238,289389.16564,252939.85020000002,323512.4169,338256.9666,199185.90738,167239.6504,198594.03012,177821.31683999998,260498.5647,396519.6119,229928.952,326488.78936,376619.24568,293406.64288,373989.3601,405454.37802,241268.55566,184837.35556,263100.77262,242771.8613,288401.04614,401814.06309999997,258705.68048,456619.94236,481157.2437,422766.62916,555279.027,503143.69348],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"] ...

# %%
sales_by_month = sales.groupby('month')['profit'].sum().reset_index()

fig = px.line(sales_by_month, x='month', y='profit', title='Monthly Profit Over Time')
fig.update_xaxes(tickangle=45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3f6fcf46-4779-4e00-8f6e-26fb1e1474fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f6fcf46-4779-4e00-8f6e-26fb1e1474fc")) {                    Plotly.newPlot(                        "3f6fcf46-4779-4e00-8f6e-26fb1e1474fc",                        [{"hovertemplate":"month=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2011-01","2011-02","2011-03","2011-04","2011-05","2011-06","2011-07","2011-08","2011-09","2011-10","2011-11","2011-12","2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12"],"xaxis":"x","y":[8321.80096,12417.90698,15303.568259999996,12902.32438,12183.8287,23415.24702,5585.0035199999975,23713.667719999998,35776.88394,25963.41834,32709.17772,40647.984,10401.637639999999,15000.09618,17992.917559999998,17366.96722,29876.70374,34407.15362,15585.38842,43573.87858,27776.18034,30662.8827,31820.7218,32950.751299999996,26810.55968,25340.0261,23433.77462,19462.038439999997,28495.694099999997,45478.413400000005,28863.8272,31023.66846,38905.667779999996,42433.222579999994,48062.996699999996,50202.87112,28001.38626,19751.699959999998,37357.260519999996,23782.301199999998,33953.55774,43778.6028,28035.87258,53542.89496,67979.4511,58209.83476,62856.5879,46916.52068],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"# ...

# %% [markdown]
# <h3 style="color: #322083; background-color: #e8e3ff; padding: 10px; border-radius: 8px;">⋆｡‧˚ʚ 💸 Market-Level Overview ɞ˚‧｡⋆ </h3>

# %% [markdown]
# <h3 style="color: #322083;">2. 🌍 Market with Most Products Sold</h3>

# %%
top_market = sales.groupby('market')['quantity'].sum().sort_values(ascending=False)

top_market_df = top_market.reset_index().sort_values('quantity', ascending=False)

# %%
fig = px.pie(
    top_market_df,
    names='market',
    values='quantity',
    title='Market Distribution'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c4dbfb3b-2fc8-4966-83c6-acf3fefbd1c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4dbfb3b-2fc8-4966-83c6-acf3fefbd1c4")) {                    Plotly.newPlot(                        "c4dbfb3b-2fc8-4966-83c6-acf3fefbd1c4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"market=%{label}\u003cbr\u003equantity=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["APAC","LATAM","US","EU","EMEA","Africa","Canada"],"legendgroup":"","name":"","showlegend":true,"values":[41226,38526,37873,37773,11517,10564,833],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"c ...

# %%
fig = px.bar(top_market_df,
             x='market',
             y='quantity',
             color='market',
             title='Top Markets by Quantity')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="52e0cb9a-3f89-4dc1-a299-3c096b8e23ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52e0cb9a-3f89-4dc1-a299-3c096b8e23ea")) {                    Plotly.newPlot(                        "52e0cb9a-3f89-4dc1-a299-3c096b8e23ea",                        [{"alignmentgroup":"True","hovertemplate":"market=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"APAC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"APAC","offsetgroup":"APAC","orientation":"v","showlegend":true,"textposition":"auto","x":["APAC"],"xaxis":"x","y":[41226],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"market=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LATAM","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"LATAM","offsetgroup":"LATAM","orientation":"v","showlegend":true,"textposition":"auto","x":["LATAM"],"xaxis":"x","y":[38526],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"market=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"US","offsetgroup":"US","orientation":"v","showlegend":true,"textposition":"auto","x":["US"],"xaxis":"x","y":[37873],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"market=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EU","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"EU","offsetgroup":"EU","orientation":"v","showlegend":true,"textposition":"auto","x":["EU"],"xaxis":"x","y":[37773],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"market=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EMEA","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"EMEA","offsetgroup":"EMEA","orientation":"v","showlegend":true,"textposition":"auto","x":["EMEA"],"xaxis":"x","y":[11517],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"market=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Africa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Africa"],"xaxis":"x","y":[10564],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"market=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canada","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"v","showlegend":true,"textposition":"auto","x":["Canada"],"xaxis":"x","y":[833],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0, ...

# %% [markdown]
# <h3 style="color: #322083;">3. 🌎 Top 10 Countries by Sales</h3>

# %%
top_country = sales.groupby('country')['sales'].sum().sort_values(ascending=False).head(10)

top_country_df = top_country.reset_index().sort_values('sales', ascending=False)

# %%
fig = px.pie(
    top_country_df,
    names='country',
    values='sales',
    title='Country Sales Distribution'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d672cdbb-ad09-4fa1-9ba7-ff21895445f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d672cdbb-ad09-4fa1-9ba7-ff21895445f8")) {                    Plotly.newPlot(                        "d672cdbb-ad09-4fa1-9ba7-ff21895445f8",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"country=%{label}\u003cbr\u003esales=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["United States","Australia","France","China","Germany","Mexico","India","United Kingdom","Indonesia","Brazil"],"legendgroup":"","name":"","showlegend":true,"values":[2297200.8603,925235.853,858931.083,700562.025,628840.0305,622590.61752,589650.105,528576.3,404887.49789999996,361106.41896],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}] ...

# %%
fig = px.bar(top_country_df,
             x='country',
             y='sales',
             color='country',
             title='Top 10 Countries by Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1f32ed15-9bb2-488c-971e-110c5d942801" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f32ed15-9bb2-488c-971e-110c5d942801")) {                    Plotly.newPlot(                        "1f32ed15-9bb2-488c-971e-110c5d942801",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[2297200.8603],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Australia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia"],"xaxis":"x","y":[925235.853],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":["France"],"xaxis":"x","y":[858931.083],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[700562.025],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[628840.0305],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mexico","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Mexico","offsetgroup":"Mexico","orientation":"v","showlegend":true,"textposition":"auto","x":["Mexico"],"xaxis":"x","y":[622590.61752],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[589650.105],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United Kingdom","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"United Kingdom","offsetgroup":"United Kingdom","orientation":"v","showlegend":true,"textposition":"auto","x":["United Kingdom"],"xaxis":"x","y":[528576.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Indonesia","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Indonesia","offsetgroup":"Indonesia","orientation":"v","showlegend":true,"textposition":"auto","x":["Indonesia"],"xaxis":"x","y":[404887.49789999996],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003esales=%{y}\u003cext ...

# %% [markdown]
# <h3 style="color: #322083;">4. 🚢 Avg Shipping Cost for Top 10 Countries by Sales</h3>

# %%
top_avg_shipping = sales.groupby('country')['shipping_cost'].mean().sort_values(ascending=False).head(10)

top_avg_shipping_df = top_avg_shipping.reset_index().sort_values('shipping_cost', ascending=False)

# %%
fig = px.bar(top_avg_shipping_df,
             x='country',
             y='shipping_cost',
             color='country',
             title='Average Shipping Cost for Top 10 Countries by Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e113f652-5531-4d38-a2c8-2693a97aad89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e113f652-5531-4d38-a2c8-2693a97aad89")) {                    Plotly.newPlot(                        "e113f652-5531-4d38-a2c8-2693a97aad89",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eshipping_cost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Taiwan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Taiwan","offsetgroup":"Taiwan","orientation":"v","showlegend":true,"textposition":"auto","x":["Taiwan"],"xaxis":"x","y":[155.66071428571428],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eshipping_cost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chad","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Chad","offsetgroup":"Chad","orientation":"v","showlegend":true,"textposition":"auto","x":["Chad"],"xaxis":"x","y":[148.97],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eshipping_cost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lesotho","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Lesotho","offsetgroup":"Lesotho","orientation":"v","showlegend":true,"textposition":"auto","x":["Lesotho"],"xaxis":"x","y":[135.65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eshipping_cost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Montenegro","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Montenegro","offsetgroup":"Montenegro","orientation":"v","showlegend":true,"textposition":"auto","x":["Montenegro"],"xaxis":"x","y":[93.9375],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eshipping_cost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slovenia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Slovenia","offsetgroup":"Slovenia","orientation":"v","showlegend":true,"textposition":"auto","x":["Slovenia"],"xaxis":"x","y":[61.22],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eshipping_cost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Republic of the Congo","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Republic of the Congo","offsetgroup":"Republic of the Congo","orientation":"v","showlegend":true,"textposition":"auto","x":["Republic of the Congo"],"xaxis":"x","y":[59.303333333333335],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eshipping_cost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central African Republic","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Central African Republic","offsetgroup":"Central African Republic","orientation":"v","showlegend":true,"textposition":"auto","x":["Central African Republic"],"xaxis":"x","y":[57.62571428571429],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eshipping_cost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Namibia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Namibia","offsetgroup":"Namibia","orientation":"v","showlegend":true,"textposition":"auto","x":["Namibia"],"xaxis":"x","y":[50.37],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eshipping_cost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bangladesh","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"v","showlegend":true,"textposition":"auto","x":[" ...

# %% [markdown]
# <h3 style="color: #322083; background-color: #e8e3ff; padding: 10px; border-radius: 8px;">༘˚⋆🛍️ ｡⋆  Category-Level Analysis 🛒 ⋆ 𖦹.✧˚</h3>

# %% [markdown]
# <h3 style="color: #322083;">5. 📊 What Category Sold the Most?</h3>

# %%
category_sales = sales.groupby('category')['quantity'].sum().sort_values()

px.bar(category_sales,
       orientation='h',
       title='TOP Category Sales',
       labels={'value': 'Quantity Sold', 'index': 'Category'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8a4dcc33-106a-4719-922c-f22bbeb0b508" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a4dcc33-106a-4719-922c-f22bbeb0b508")) {                    Plotly.newPlot(                        "8a4dcc33-106a-4719-922c-f22bbeb0b508",                        [{"alignmentgroup":"True","hovertemplate":"variable=quantity\u003cbr\u003eQuantity Sold=%{x}\u003cbr\u003ecategory=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"quantity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"quantity","offsetgroup":"quantity","orientation":"h","showlegend":true,"textposition":"auto","x":[34954,35176,108182],"xaxis":"x","y":["Furniture","Technology","Office Supplies"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scatt ...

# %% [markdown]
# <h3 style="color: #322083;">6. 💼 Most Profitable Category</h3>

# %%
cat_profit = sales.groupby('category')['profit'].sum().sort_values()

# convert to DataFrame
cat_profit_df = cat_profit.reset_index()

# pie chart
fig = px.pie(
    cat_profit_df,
    names='category',
    values='profit',
    title='Profit Distribution Categories'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="248959a6-1d9f-48a7-8ec4-7faadfdd892d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("248959a6-1d9f-48a7-8ec4-7faadfdd892d")) {                    Plotly.newPlot(                        "248959a6-1d9f-48a7-8ec4-7faadfdd892d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"category=%{label}\u003cbr\u003eprofit=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Furniture","Office Supplies","Technology"],"legendgroup":"","name":"","showlegend":true,"values":[286782.2538,518473.8343,663778.73318],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{ ...

# %%
px.bar(cat_profit,
       orientation = 'h',
       title='TOP Profitable Categories',
       labels= {'value': 'Profit', 'index': 'Category'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c7012f72-c716-463e-9d38-e194de57e922" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7012f72-c716-463e-9d38-e194de57e922")) {                    Plotly.newPlot(                        "c7012f72-c716-463e-9d38-e194de57e922",                        [{"alignmentgroup":"True","hovertemplate":"variable=profit\u003cbr\u003eProfit=%{x}\u003cbr\u003ecategory=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"profit","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"profit","offsetgroup":"profit","orientation":"h","showlegend":true,"textposition":"auto","x":[286782.2538,518473.8343,663778.73318],"xaxis":"x","y":["Furniture","Office Supplies","Technology"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"sc ...

# %% [markdown]
# <h3 style="color: #322083;">7. 🧾 Total Sales by Category & Sub-Category</h3>

# %%
cat_subcat_sales = sales.groupby(['category', 'sub_category'])['sales'].sum().reset_index()

fig = px.bar(cat_subcat_sales, x='sub_category', y='sales', color='category', title='Sales by Category and Sub-Category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6dab9801-569b-4820-89f7-8f0e09a22acb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dab9801-569b-4820-89f7-8f0e09a22acb")) {                    Plotly.newPlot(                        "6dab9801-569b-4820-89f7-8f0e09a22acb",                        [{"alignmentgroup":"True","hovertemplate":"category=Furniture\u003cbr\u003esub_category=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Furniture","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Furniture","offsetgroup":"Furniture","orientation":"v","showlegend":true,"textposition":"auto","x":["Bookcases","Chairs","Furnishings","Tables"],"xaxis":"x","y":[1466572.2418,1501681.7641999999,385578.2559,757041.9244],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Office Supplies\u003cbr\u003esub_category=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Office Supplies","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Office Supplies","offsetgroup":"Office Supplies","orientation":"v","showlegend":true,"textposition":"auto","x":["Appliances","Art","Binders","Envelopes","Fasteners","Labels","Paper","Storage","Supplies"],"xaxis":"x","y":[1011064.3049999999,372091.9659,461911.50570000004,170904.3016,83242.3159,73404.03,244291.7194,1127085.8614,243074.2206],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Technology\u003cbr\u003esub_category=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technology","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Technology","offsetgroup":"Technology","orientation":"v","showlegend":true,"textposition":"auto","x":["Accessories","Copiers","Machines","Phones"],"xaxis":"x","y":[749237.0185,1509436.27328,779060.0671000001,1706824.1392],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4 ...

# %%
cat_subcat_sales = sales.groupby(['category', 'sub_category'])['sales'].sum().reset_index()

# Sort categories by total sales (descending)
category_order = (
    cat_subcat_sales.groupby('category')['sales']
    .sum()
    .sort_values(ascending=False)
    .index.tolist()
)

# Sort sub-categories by total sales (descending)
subcat_order = (
    cat_subcat_sales.groupby('sub_category')['sales']
    .sum()
    .sort_values(ascending=False)
    .index.tolist()
)

# Pivot the data so that each sub-category becomes a column
pivot_df = cat_subcat_sales.pivot(index='category', columns='sub_category', values='sales').fillna(0)

# Reorder the pivoted data based on the sorted category and sub-category
pivot_df = pivot_df.loc[category_order, subcat_order]

# Create a stacked bar chart using Plotly Graph Objects
fig = go.Figure()

# Add a bar for each sub-category
for subcat in pivot_df.columns:
    fig.add_bar(
        x=pivot_df.index,
        y=pivot_df[subcat],
        name=subcat
    )

# Final layout configuration
fig.update_layout(
    barmode='stack',
    title='Stacked Bar Chart: Sales by Category and Sub-Category',
    xaxis_title='Category',
    yaxis_title='Total Sales'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bcfac9fa-0910-40a8-a0dd-a75e2d48e4f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcfac9fa-0910-40a8-a0dd-a75e2d48e4f8")) {                    Plotly.newPlot(                        "bcfac9fa-0910-40a8-a0dd-a75e2d48e4f8",                        [{"name":"Phones","x":["Technology","Furniture","Office Supplies"],"y":[1706824.1392,0.0,0.0],"type":"bar"},{"name":"Copiers","x":["Technology","Furniture","Office Supplies"],"y":[1509436.27328,0.0,0.0],"type":"bar"},{"name":"Chairs","x":["Technology","Furniture","Office Supplies"],"y":[0.0,1501681.7641999999,0.0],"type":"bar"},{"name":"Bookcases","x":["Technology","Furniture","Office Supplies"],"y":[0.0,1466572.2418,0.0],"type":"bar"},{"name":"Storage","x":["Technology","Furniture","Office Supplies"],"y":[0.0,0.0,1127085.8614],"type":"bar"},{"name":"Appliances","x":["Technology","Furniture","Office Supplies"],"y":[0.0,0.0,1011064.3049999999],"type":"bar"},{"name":"Machines","x":["Technology","Furniture","Office Supplies"],"y":[779060.0671000001,0.0,0.0],"type":"bar"},{"name":"Tables","x":["Technology","Furniture","Office Supplies"],"y":[0.0,757041.9244,0.0],"type":"bar"},{"name":"Accessories","x":["Technology","Furniture","Office Supplies"],"y":[749237.0185,0.0,0.0],"type":"bar"},{"name":"Binders","x":["Technology","Furniture","Office Supplies"],"y":[0.0,0.0,461911.50570000004],"type":"bar"},{"name":"Furnishings","x":["Technology","Furniture","Office Supplies"],"y":[0.0,385578.2559,0.0],"type":"bar"},{"name":"Art","x":["Technology","Furniture","Office Supplies"],"y":[0.0,0.0,372091.9659],"type":"bar"},{"name":"Paper","x":["Technology","Furniture","Office Supplies"],"y":[0.0,0.0,244291.7194],"type":"bar"},{"name":"Supplies","x":["Technology","Furniture","Office Supplies"],"y":[0.0,0.0,243074.2206],"type":"bar"},{"name":"Envelopes","x":["Technology","Furniture","Office Supplies"],"y":[0.0,0.0,170904.3016],"type":"bar"},{"name":"Fasteners","x":["Technology","Furniture","Office Supplies"],"y":[0.0,0.0,83242.3159],"type":"bar"},{"name":"Labels","x":["Technology","Furniture","Office Supplies"],"y":[0.0,0.0,73404.03],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8 ...

# %% [markdown]
# <h3 style="color: #322083; background-color: #e8e3ff; padding: 10px; border-radius: 8px;">.⋆✴︎˚｡  📦 Subcategory & Product-Level Analysis ₊˚✧</h3>

# %% [markdown]
# <h3 style="color: #322083;">8. 📚 Most Selling Products in Each Subcategory</h3>

# %%
top_per_sub = sales.groupby(['sub_category', 'product_name'])['quantity'].sum().reset_index()
top_per_sub = top_per_sub.sort_values(['sub_category','quantity'], ascending=[True, False]).drop_duplicates('sub_category')

#  reset index
top_per_sub = top_per_sub.reset_index(drop=True).sort_values('quantity', ascending=False)

fig = px.bar(top_per_sub, x='sub_category', y='quantity', color='product_name', title='Top Selling Product per Sub-Category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4fd46e03-4b4f-4f89-ac34-50aa1b54e72a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fd46e03-4b4f-4f89-ac34-50aa1b54e72a")) {                    Plotly.newPlot(                        "4fd46e03-4b4f-4f89-ac34-50aa1b54e72a",                        [{"alignmentgroup":"True","hovertemplate":"product_name=Cardinal Index Tab, Clear\u003cbr\u003esub_category=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardinal Index Tab, Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cardinal Index Tab, Clear","offsetgroup":"Cardinal Index Tab, Clear","orientation":"v","showlegend":true,"textposition":"auto","x":["Binders"],"xaxis":"x","y":[337],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_name=Eldon File Cart, Single Width\u003cbr\u003esub_category=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eldon File Cart, Single Width","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Eldon File Cart, Single Width","offsetgroup":"Eldon File Cart, Single Width","orientation":"v","showlegend":true,"textposition":"auto","x":["Storage"],"xaxis":"x","y":[321],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_name=Sanford Pencil Sharpener, Water Color\u003cbr\u003esub_category=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sanford Pencil Sharpener, Water Color","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Sanford Pencil Sharpener, Water Color","offsetgroup":"Sanford Pencil Sharpener, Water Color","orientation":"v","showlegend":true,"textposition":"auto","x":["Art"],"xaxis":"x","y":[259],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_name=Stockwell Paper Clips, Assorted Sizes\u003cbr\u003esub_category=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stockwell Paper Clips, Assorted Sizes","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Stockwell Paper Clips, Assorted Sizes","offsetgroup":"Stockwell Paper Clips, Assorted Sizes","orientation":"v","showlegend":true,"textposition":"auto","x":["Fasteners"],"xaxis":"x","y":[253],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_name=Enermax Note Cards, Premium\u003cbr\u003esub_category=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enermax Note Cards, Premium","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Enermax Note Cards, Premium","offsetgroup":"Enermax Note Cards, Premium","orientation":"v","showlegend":true,"textposition":"auto","x":["Paper"],"xaxis":"x","y":[171],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_name=Apple Smart Phone, Full Size\u003cbr\u003esub_category=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Apple Smart Phone, Full Size","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Apple Smart Phone, Full Size","offsetgroup":"Apple Smart Phone, Full Size","orientation":"v","showlegend":true,"textposition":"auto","x":["Phones"],"xaxis":"x","y":[171],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_name=Staples\u003cbr\u003esub_category=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Staples","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Staples","offsetgroup":"Staples","orientation":"v","showlegend":true,"textposition":"auto","x":["Envelopes"],"xaxis":"x","y":[170],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_name=Hon Executive ...

# %% [markdown]
# <h3 style="color: #322083;">9. 📦 Most Selling Products (by quantity)</h3>

# %%
# Grouping and sort data by qty
top_selling = sales.groupby('product_name')['quantity'].sum().sort_values(ascending=False).head(10)

# Convert to DataFrame
top_selling_df = top_selling.reset_index()

# Sort DataFrame ascending
top_selling_df = top_selling_df.sort_values('quantity')

# Plot
fig = px.bar(
    top_selling_df,
    x='quantity',
    y='product_name',
    orientation='h',
    title='Top 10 Most Selling Products by Quantity',
    labels={'quantity': 'Quantity Sold', 'product_name': 'Product Name'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1a88eeca-f4fb-4b2a-b859-4dfead423f1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a88eeca-f4fb-4b2a-b859-4dfead423f1c")) {                    Plotly.newPlot(                        "1a88eeca-f4fb-4b2a-b859-4dfead423f1c",                        [{"alignmentgroup":"True","hovertemplate":"Quantity Sold=%{x}\u003cbr\u003eProduct Name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[242,250,251,252,253,259,262,321,337,876],"xaxis":"x","y":["Stanley Pencil Sharpener, Water Color","Smead File Cart, Single Width","Ibico Index Tab, Clear","Avery Index Tab, Clear","Stockwell Paper Clips, Assorted Sizes","Sanford Pencil Sharpener, Water Color","Rogers File Cart, Single Width","Eldon File Cart, Single Width","Cardinal Index Tab, Clear","Staples"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorba ...

# %% [markdown]
# <h3 style="color: #322083;">10. 💰 Top 10 Products by Sales</h3>

# %%
top_sales = sales.groupby('product_name')['sales'].sum().sort_values(ascending=False).head(10)
top_sales
# Out:
# product_name
# Apple Smart Phone, Full Size                                86935.7786
# Cisco Smart Phone, Full Size                                76441.5306
# Motorola Smart Phone, Full Size                             73156.3030
# Nokia Smart Phone, Full Size                                71904.5555
# Canon imageCLASS 2200 Advanced Copier                       61599.8240
# Hon Executive Leather Armchair, Adjustable                  58193.4841
# Office Star Executive Leather Armchair, Adjustable          50661.6840
# Harbour Creations Executive Leather Armchair, Adjustable    50121.5160
# Samsung Smart Phone, Cordless                               48653.4600
# Nokia Smart Phone, with Caller ID                           47877.7857
# Name: sales, dtype: float64

# %%
# Convert to DataFrame
top_sales_df = top_sales.reset_index()

# Plotly bar chart with correct sort order
fig = px.bar(
    top_sales_df,
    x='sales',
    y='product_name',
    orientation='h',
    title='Top 10 Products by Total Sales',
    labels={'sales': 'Total Sales', 'product_name': 'Product Name'},
    category_orders={'product_name': top_sales_df['product_name'].tolist()}
)

fig.update_layout(yaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4fbc2a58-6729-44b7-a151-663c6f09dd52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fbc2a58-6729-44b7-a151-663c6f09dd52")) {                    Plotly.newPlot(                        "4fbc2a58-6729-44b7-a151-663c6f09dd52",                        [{"alignmentgroup":"True","hovertemplate":"Total Sales=%{x}\u003cbr\u003eProduct Name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[86935.7786,76441.5306,73156.303,71904.5555,61599.82399999999,58193.484099999994,50661.683999999994,50121.515999999996,48653.460000000014,47877.7857],"xaxis":"x","y":["Apple Smart Phone, Full Size","Cisco Smart Phone, Full Size","Motorola Smart Phone, Full Size","Nokia Smart Phone, Full Size","Canon imageCLASS 2200 Advanced Copier","Hon Executive Leather Armchair, Adjustable","Office Star Executive Leather Armchair, Adjustable","Harbour Creations Executive Leather Armchair, Adjustable","Samsung Smart Phone, Cordless","Nokia Smart Phone, with Caller ID"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay ...

# %% [markdown]
# <h3 style="color: #322083;">11. 💸 Most Profitable Products</h3>

# %%
# Group, sum, sort
top_profit = sales.groupby('product_name')['profit'].sum().sort_values(ascending=False).head(10)

# Convert to DataFrame & sort again (ascending, so largest is at the top)
top_profit_df = top_profit.reset_index().sort_values('profit')

# Plot
fig = px.bar(
    top_profit_df,
    x='profit',
    y='product_name',
    orientation='h',
    title='Top 10 Most Profitable Products',
    labels={'profit': 'Total Profit', 'product_name': 'Product Name'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3aefa2a3-0e74-4524-b909-0cd57a1c8259" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3aefa2a3-0e74-4524-b909-0cd57a1c8259")) {                    Plotly.newPlot(                        "3aefa2a3-0e74-4524-b909-0cd57a1c8259",                        [{"alignmentgroup":"True","hovertemplate":"Total Profit=%{x}\u003cbr\u003eProduct Name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[8955.018,9465.325699999998,9786.640800000001,9938.1955,10427.326000000001,10672.073,11807.968999999997,17027.113,17238.5206,25199.927999999996],"xaxis":"x","y":["Belkin Router, USB","Nokia Smart Phone, with Caller ID","Cisco Smart Phone, with Caller ID","Nokia Smart Phone, Full Size","Harbour Creations Executive Leather Armchair, Adjustable","Sauder Classic Bookcase, Traditional","Hoover Stove, Red","Motorola Smart Phone, Full Size","Cisco Smart Phone, Full Size","Canon imageCLASS 2200 Advanced Copier"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"p ...

# %% [markdown]
# <h3 style="color: #322083; background-color: #e8e3ff; padding: 10px; border-radius: 8px;">⋆⭒˚.⋆ 🛒 Customer Behavior ೃ࿔ *:･</h3>

# %% [markdown]
# <h3 style="color: #322083;">12. 👥 Most Profitable Customer Segments</h3>

# %%
top_customer = sales.groupby('segment')['profit'].sum().sort_values(ascending=False)

top_customer_df = top_customer.reset_index().sort_values('profit', ascending=False)

# %%
fig = px.pie(
    top_customer_df,
    names='segment',
    values='profit',
    title='Profit Distribution by Customer Segment'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b0a0ef42-4840-43bd-823b-fa4670b24b1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0a0ef42-4840-43bd-823b-fa4670b24b1d")) {                    Plotly.newPlot(                        "b0a0ef42-4840-43bd-823b-fa4670b24b1d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"segment=%{label}\u003cbr\u003eprofit=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Consumer","Corporate","Home Office"],"legendgroup":"","name":"","showlegend":true,"values":[749239.78206,442785.85865999997,277009.18056],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar": ...

# %%
fig = px.bar(
    top_customer_df,
    x='segment',
    y='profit',
    title='Top Customer Segments by Profit',
    labels={'segment': 'Customer Segment', 'profit': 'Total Profit'}
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="95b1dfd7-4500-4a79-bf58-c80f630d3ed0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95b1dfd7-4500-4a79-bf58-c80f630d3ed0")) {                    Plotly.newPlot(                        "95b1dfd7-4500-4a79-bf58-c80f630d3ed0",                        [{"alignmentgroup":"True","hovertemplate":"Customer Segment=%{x}\u003cbr\u003eTotal Profit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Consumer","Corporate","Home Office"],"xaxis":"x","y":[749239.78206,442785.85865999997,277009.18056],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo ...

# %% [markdown]
# <h3 style="color: #322083;">13. 🧑‍💼 Top 10 Most Profitable Customers</h3>

# %%
top_profit_cust = sales.groupby('customer_name')['profit'].sum().sort_values(ascending=False).head(10)

top_profit_cust_df = top_profit_cust.reset_index().sort_values('profit', ascending=False)

# %%
fig = px.bar(top_profit_cust_df,
             x='customer_name',
             y='profit',
             color='customer_name',
             title='Top 10 Most Profitable Customers')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2b4804c9-ae4e-4fa9-a8c9-eabba538b0a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b4804c9-ae4e-4fa9-a8c9-eabba538b0a8")) {                    Plotly.newPlot(                        "2b4804c9-ae4e-4fa9-a8c9-eabba538b0a8",                        [{"alignmentgroup":"True","hovertemplate":"customer_name=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tamara Chand","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Tamara Chand","offsetgroup":"Tamara Chand","orientation":"v","showlegend":true,"textposition":"auto","x":["Tamara Chand"],"xaxis":"x","y":[8672.898899999998],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"customer_name=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Raymond Buch","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Raymond Buch","offsetgroup":"Raymond Buch","orientation":"v","showlegend":true,"textposition":"auto","x":["Raymond Buch"],"xaxis":"x","y":[8453.0495],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"customer_name=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sanjit Chand","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Sanjit Chand","offsetgroup":"Sanjit Chand","orientation":"v","showlegend":true,"textposition":"auto","x":["Sanjit Chand"],"xaxis":"x","y":[8205.3799],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"customer_name=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hunter Lopez","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Hunter Lopez","offsetgroup":"Hunter Lopez","orientation":"v","showlegend":true,"textposition":"auto","x":["Hunter Lopez"],"xaxis":"x","y":[7816.567779999999],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"customer_name=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bill Eplett","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Bill Eplett","offsetgroup":"Bill Eplett","orientation":"v","showlegend":true,"textposition":"auto","x":["Bill Eplett"],"xaxis":"x","y":[7410.0053],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"customer_name=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Harry Marie","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Harry Marie","offsetgroup":"Harry Marie","orientation":"v","showlegend":true,"textposition":"auto","x":["Harry Marie"],"xaxis":"x","y":[6958.2864],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"customer_name=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Susan Pistek","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Susan Pistek","offsetgroup":"Susan Pistek","orientation":"v","showlegend":true,"textposition":"auto","x":["Susan Pistek"],"xaxis":"x","y":[6484.40726],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"customer_name=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mike Gockenbach","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Mike Gockenbach","offsetgroup":"Mike Gockenbach","orientation":"v","showlegend":true,"textposition":"auto","x":["Mike Gockenbach"],"xaxis":"x","y":[6458.6762],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"customer_name=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adrian Barton","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Adrian Barton","offsetgroup":"Adrian Barton","orientation":"v" ...

# %% [markdown]
# <h3 style="color: #322083; background-color: #e8e3ff; padding: 10px; border-radius: 8px;">⋆⭒˚.⋆ 🚚 Shipping Behavior ೃ࿔ *:･</h3>

# %% [markdown]
# <h3 style="color: #322083;">14. 🚚 Shipping Modes with Most Products Sold</h3>

# %%
top_shipping = sales.groupby('ship_mode')['quantity'].sum().sort_values(ascending=False)

top_shipping_df = top_shipping.reset_index().sort_values('quantity', ascending=False)

# %%
fig = px.pie(
    top_shipping_df,
    names='ship_mode',
    values='quantity',
    title='Shipping Mode Distribution'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3f127eb5-ee4f-4316-bb5f-a83a10ab030a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f127eb5-ee4f-4316-bb5f-a83a10ab030a")) {                    Plotly.newPlot(                        "3f127eb5-ee4f-4316-bb5f-a83a10ab030a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"ship_mode=%{label}\u003cbr\u003equantity=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Standard Class","Second Class","First Class","Same Day"],"legendgroup":"","name":"","showlegend":true,"values":[107319,35724,26039,9230],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorba ...

# %%
fig = px.bar(top_shipping_df,
             x='ship_mode',
             y='quantity',
             title='Top Shipping Modes by Quantity')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="59a95aaa-0c7d-4fa5-8355-8c8a21895491" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59a95aaa-0c7d-4fa5-8355-8c8a21895491")) {                    Plotly.newPlot(                        "59a95aaa-0c7d-4fa5-8355-8c8a21895491",                        [{"alignmentgroup":"True","hovertemplate":"ship_mode=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Standard Class","Second Class","First Class","Same Day"],"xaxis":"x","y":[107319,35724,26039,9230],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{ ...

# %% [markdown]
# <h3 style="color: #322083;">15. 📦 Visualize Category by Shipping Mode</h3>

# %%
top_shipping_cat = sales.groupby(['ship_mode', 'category'])['quantity'].sum().reset_index()

top_shipping_cat_df = top_shipping_cat.sort_values('quantity', ascending=False)

# %%
#  Stacked
fig = px.bar(top_shipping_cat_df,
             x='ship_mode',
             y='quantity',
             color='category',
             title='Top Shipping Modes by Category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="499abd4e-ffdc-4694-8d83-9c0089ba33f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("499abd4e-ffdc-4694-8d83-9c0089ba33f5")) {                    Plotly.newPlot(                        "499abd4e-ffdc-4694-8d83-9c0089ba33f5",                        [{"alignmentgroup":"True","hovertemplate":"category=Office Supplies\u003cbr\u003eship_mode=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Office Supplies","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Office Supplies","offsetgroup":"Office Supplies","orientation":"v","showlegend":true,"textposition":"auto","x":["Standard Class","Second Class","First Class","Same Day"],"xaxis":"x","y":[64985,21637,15922,5638],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Furniture\u003cbr\u003eship_mode=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Furniture","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Furniture","offsetgroup":"Furniture","orientation":"v","showlegend":true,"textposition":"auto","x":["Standard Class","Second Class","First Class","Same Day"],"xaxis":"x","y":[21228,6891,5034,1801],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Technology\u003cbr\u003eship_mode=%{x}\u003cbr\u003equantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technology","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Technology","offsetgroup":"Technology","orientation":"v","showlegend":true,"textposition":"auto","x":["Standard Class","Second Class","First Class","Same Day"],"xaxis":"x","y":[21106,7196,5083,1791],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777 ...

# %% [markdown]
# | **Insight**                                                               | **Recommendation**                                                              | **Actionable Items**                                                              |
# |---------------------------------------------------------------------------|----------------------------------------------------------------------------------|-----------------------------------------------------------------------------------|
# | Sales and profit grew from 2011–2014 despite monthly fluctuations         | Strengthen seasonal and periodic marketing strategies                           | Build an annual promotion calendar based on historical trends                    |
# | Top-performing markets: US, APAC, LATAM                                   | Focus resources and campaigns on high-potential regions                         | Allocate more marketing budget to US, APAC, and LATAM                            |
# | US contributed 29% of total sales (2.29M), followed by Australia & France | Prioritize the US market                                                        | Launch loyalty programs and localized campaigns in the US                        |
# | Best-selling category: Office Supplies                                    | Maintain strong inventory and availability in this category                     | Optimize supply chain for Office Supplies                                        |
# | Top products by volume: Staples, Index Tab Clear, Eldon File Cart         | Keep top-selling products as core offerings                                     | Bundle popular items and run focused promotions                                  |
# | Most profitable category: Technology                                      | Promote and expand high-margin tech offerings                                   | Run digital campaigns and upsell tech products                                   |
# | Most profitable products: Canon Copier, Cisco Smartphone                  | Highlight these in B2B and premium offerings                                    | Create B2B partnerships and special offers for top tech products                 |
# | Consumer segment drives the most revenue                                  | Deepen segmentation for tailored marketing                                      | Run targeted campaigns for Consumer; explore potential in Corporate/SMB segments |
# | Most loyal customers: Tamara Chand, Raymond Buch, Sanjit Chan             | Improve retention through rewards                                               | Offer early access, loyalty discounts, and referral programs                     |
# | Customer base includes both high-value and low-value segments             | Segment customers for loyalty and reactivation strategies                       | Build lifecycle-based segments (e.g. loyal, at-risk, inactive); tailor campaigns |
# | Most used shipping: Standard Class (60%), then Second, First, Same Day    | Review shipping efficiency for customer satisfaction                            | Optimize logistics for Standard Class and offer premium shipping for VIPs        |
# | Shipping costs vary by country due to volume and frequency                | Adjust pricing and logistics strategy by region                                 | Recalculate costs and offer shipping discounts in high-cost countries            |
